# %%
import pandas as pd

# %%
df=pd.read_csv('../data/7-10-22_Ficial-reanimation_data_extraction_with_time_to_reinervation.csv')
df
# Out:
#          PMID database                                              title  \
# 0     1908974  Pub-med  Hypoglossal-facial nerve interpositional-jump ...
# 1     2025755  Pub-med  Reanimation for facial palsy using gracilis mu...
# 2     2248739  Pub-med  Simultaneous 'dual system' rehabilitation in t...
# 3     2359779  Pub-med  Results of management of facial palsy with mic...
# 4     3083357  Pub-med  Preliminary observations after facial rehabili...
# ..        ...      ...                                                ...
# 101  33976066  Pub-med  The Chimeric Scapulodorsal Vascularized Latiss...
# 102  34024072  Pub-med  Dual-innervated multivector muscle transfer us...
# 103  34727487  Pub-med  End-to-Trunk Masseteric to Facial Nerve Transf...
# 104  34760845  Pub-med  Two-Stage Dual-Nerve Facial Reanimation: Outco...
# 105  35198351  Pub-med  Supercharging the Smile: A Novel Dual Nerve Tr...
#
#                                               abstract  nerve_transfer  \
# ...
